# %%
# Imports

# %%
# !pip install protobuf==3.20
# !pip install tensorflow==2.8.0
# !pip install matplotlib
# Out:
# Requirement already satisfied: protobuf==3.20 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (3.20.0)
# Requirement already satisfied: tensorflow==2.8.0 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (2.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (0.26.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (3.7.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (1.2.0)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (2.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (14.0.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (1.1.2)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (2.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (3.3.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (2.8.0.dev2021122109)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (1.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (3.20.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (1.14.1)
# Requirement already satisfied: gast>=0.2.1 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (0.5.3)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (2.8.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (4.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (1.48.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (0.2.0)
# Requirement already satisfied: setuptools in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (61.2.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorflow==2.8.0) (1.23.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.8.0) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.9.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.2.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.28.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (4.12.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.26.11)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.2.0)
# Requirement already satisfied: matplotlib in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (3.5.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (4.34.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (1.23.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\fagai\anaconda3\envs\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
print(tf.__version__)
# Out:
# 2.8.0

# %%
dataset_dir = '../dataset'

# %%
BATCH_SIZE = 32
IMAGE_HEIGHT = 256
IMAGE_WIDTH = 256
IMAGE_SIZE = (IMAGE_HEIGHT, IMAGE_WIDTH)
CHANNELS=3
EPOCHS=20

# %%
dataset = tf.keras.utils.image_dataset_from_directory(dataset_dir,
                                                      shuffle = True,
                                                      batch_size = BATCH_SIZE,
                                                      image_size = IMAGE_SIZE)
# Out:
# Found 4000 files belonging to 4 classes.

# %%
# Exploring the dataset

# %%
class_names = dataset.class_names

plt.figure(figsize=(10, 10))

for images, labels in dataset.take(1):
    
  for i in range(12):
    
    ax = plt.subplot(3, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
print("Length of dataset is {}. Remember that batch size of images is 32. Total of images is 4000 = 125 x 32.".format(len(dataset)))
# Out:
# Length of dataset is 125. Remember that batch size of images is 32. Total of images is 4000 = 125 x 32.

# %%
# Training Dataset, Validation Dataset and Test Dataset

# %%
total_dataset_len = len(dataset)

# %%
# 80 % Training Dataset
# 20 % Validation Dataset & Test Dataset

# %%
training_dataset_len = int(total_dataset_len * 0.8)

training_dataset = dataset.take(training_dataset_len)
print(training_dataset_len)
# Out:
# 100

# %%
# To be used for Validation & Testing
rest_of_dataset = dataset.skip(training_dataset_len)
rest_of_dataset_len = len(rest_of_dataset) 
print(rest_of_dataset_len)
# Out:
# 25

# %%
validation_dataset_len = int(rest_of_dataset_len * 0.5)
validation_dataset = rest_of_dataset.take(validation_dataset_len)
validation_dataset_len
# Out:
# 12

# %%
test_dataset = rest_of_dataset.skip(validation_dataset_len)
print(len(test_dataset))
# Out:
# 13

# %%
# Cache, Shuffle, and Prefetch the dataset

# %%
def optimize(dataset):
    
    return dataset.cache().shuffle(100).prefetch(tf.data.AUTOTUNE)

training_dataset = optimize(training_dataset)
validation_dataset = optimize(validation_dataset)
test_dataset = optimize(test_dataset)

# %%
# Data augmentation

# %%
data_augmentation = tf.keras.Sequential(
  [
    tf.keras.layers.RandomFlip("horizontal_and_vertical", input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3)),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in training_dataset.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
# Model architecture

# %%
model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(len(class_names))
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 256, 256, 3)       0
#
#  rescaling (Rescaling)       (None, 256, 256, 3)       0
#
#  conv2d (Conv2D)             (None, 256, 256, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 32, 32, 64)        0
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 128)               8388736
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 8,412,836
# Trainable params: 8,412,836
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    training_dataset,
    batch_size = BATCH_SIZE,
    validation_data = validation_dataset,
    verbose = 1,
    epochs = EPOCHS
)
# Out:
# Epoch 1/20
# 100/100 [==============================] - 74s 731ms/step - loss: 0.6242 - accuracy: 0.7212 - val_loss: 0.5030 - val_accuracy: 0.8047
# Epoch 2/20
# 100/100 [==============================] - 73s 726ms/step - loss: 0.3329 - accuracy: 0.8487 - val_loss: 0.4161 - val_accuracy: 0.8255
# Epoch 3/20
# 100/100 [==============================] - 73s 729ms/step - loss: 0.3012 - accuracy: 0.8722 - val_loss: 0.2651 - val_accuracy: 0.8620
# Epoch 4/20
# 100/100 [==============================] - 73s 731ms/step - loss: 0.2583 - accuracy: 0.8866 - val_loss: 0.2634 - val_accuracy: 0.8802
# Epoch 5/20
# 100/100 [==============================] - 74s 738ms/step - loss: 0.2496 - accuracy: 0.8944 - val_loss: 0.2993 - val_accuracy: 0.8776
# Epoch 6/20
# 100/100 [==============================] - 73s 732ms/step - loss: 0.2202 - accuracy: 0.9166 - val_loss: 0.2346 - val_accuracy: 0.8906
# Epoch 7/20
# 100/100 [==============================] - 73s 733ms/step - loss: 0.2345 - accuracy: 0.9028 - val_loss: 0.2219 - val_accuracy: 0.9089
# Epoch 8/20
# 100/100 [==============================] - 76s 761ms/step - loss: 0.2006 - accuracy: 0.9200 - val_loss: 0.2869 - val_accuracy: 0.8724
# Epoch 9/20
# 100/100 [==============================] - 75s 754ms/step - loss: 0.2922 - accuracy: 0.8750 - val_loss: 0.2511 - val_accuracy: 0.8776
# Epoch 10/20
# 100/100 [==============================] - 75s 752ms/step - loss: 0.2059 - accuracy: 0.9144 - val_loss: 0.1893 - val_accuracy: 0.9115
# Epoch 11/20
# 100/100 [==============================] - 75s 753ms/step - loss: 0.1910 - accuracy: 0.9216 - val_loss: 0.1894 - val_accuracy: 0.9193
# Epoch 12/20
# 100/100 [==============================] - 76s 757ms/step - loss: 0.1831 - accuracy: 0.9269 - val_loss: 0.2363 - val_accuracy: 0.9010
# Epoch 13/20
# 100/100 [==============================] - 74s 743ms/step - loss: 0.1794 - accuracy: 0.9241 - val_loss: 0.3486 - val_accuracy: 0.8516
# Epoch 14/20
# 100/100 [==============================] - 73s 733ms/step - loss: 0.1964 - accuracy: 0.9178 - val_loss: 0.2008 - val_accuracy: 0.9271
# Epoch 15/20
# 100/100 [==============================] - 73s 732ms/step - loss: 0.1711 - accuracy: 0.9284 - val_loss: 0.2622 - val_accuracy: 0.8932
# Epoch 16/20
# 100/100 [==============================] - 73s 729ms/step - loss: 0.1592 - accuracy: 0.9353 - val_loss: 0.1677 - val_accuracy: 0.9219
# Epoch 17/20
# 100/100 [==============================] - 74s 741ms/step - loss: 0.1413 - accuracy: 0.9456 - val_loss: 0.1673 - val_accuracy: 0.9323
# Epoch 18/20
# 100/100 [==============================] - 89s 889ms/step - loss: 0.1601 - accuracy: 0.9403 - val_loss: 0.1510 - val_accuracy: 0.9349
# Epoch 19/20
# 100/100 [==============================] - 82s 818ms/step - loss: 0.1565 - accuracy: 0.9406 - val_loss: 0.2312 - val_accuracy: 0.9167
# Epoch 20/20
# 100/100 [==============================] - 81s 811ms/step - loss: 0.1499 - accuracy: 0.9397 - val_loss: 0.1863 - val_accuracy: 0.9167

# %%
scores = model.evaluate(test_dataset)
scores
# Out:
# 13/13 [==============================] - 4s 161ms/step - loss: 0.1516 - accuracy: 0.9423
# [0.1515776515007019, 0.942307710647583]

# %%
# Plotting the loss and accuracy curves

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))

plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()

# %%
def predict(model, img):
    
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    score = tf.nn.softmax(predictions[0])
    predicted_class = class_names[np.argmax(score)]
    confidence = round(100 * np.max(score), 2) 
    
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))

for images, labels in test_dataset.take(1):
    
    for i in range(9):
        
        ax = plt.subplot(3, 3, i + 1)
        
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")

# %%
# Save the model

# %%
path = '../model'

os.mkdir(path)
model.save(path)
# Out:
# INFO:tensorflow:Assets written to: ../model\assets
